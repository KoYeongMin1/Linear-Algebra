# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
path = "/home/oem/KYM/"

cat = cv2.imread(path + "/고양이.png")
cat = cv2.cvtColor(cat, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(cat)
plt.show()

# %%
cat = np.array(cat)
print(np.shape(cat))
# Out:
# (866, 683, 3)

# %%
print(cat)
# Out:
# [[[ 52  29  12]
#   [ 53  30  12]
#   [ 54  31  13]
#   ...
#   [134 103  71]
#   [136 104  72]
#   [142 110  78]]
#
#  [[ 51  28  11]
#   [ 53  30  12]
#   [ 56  32  14]
#   ...
#   [135 105  71]
#   [138 107  73]
#   [142 110  77]]
#
#  [[ 53  28  12]
#   [ 53  29  11]
#   [ 56  31  14]
#   ...
#   [137 107  72]
#   [140 109  74]
#   [141 108  74]]
#
#  ...
#
#  [[ 43  25  11]
#   [ 44  25  10]
#   [ 44  26  10]
#   ...
#   [112 108  97]
#   [112 108  97]
#   [114 109  99]]
#
#  [[ 42  25   9]
#   [ 42  25   9]
#   [ 43  26  10]
#   ...
#   [112 107  97]
#   [112 108  97]
#   [115 111 100]]
#
#  [[ 43  25   9]
#   [ 43  26  10]
#   [ 44  26   9]
#   ...
#   [111 106  96]
#   [112 108  98]
#   [115 111 100]]]
